# %% [markdown]
# # Convolution Image Net

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from utils.nn_visualization import variable_summaries
from utils.data import init_model_logging
from utils.nn_graph import simple_layer
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import os
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# ## Load data

# %%
data = input_data.read_data_sets('/data/fashion/', one_hot=True)
img_shape = (28, 28)
class_id2class_name_mapping = {
    0: 'T-shirt/top',
    1: 'Trouser',
    2: 'Pullover',
    3: 'Dress',
    4: 'Coat',
    5: 'Sandal',
    6: 'Shirt',
    7: 'Sneaker',
    8: 'Bag',
    9: 'Ankle boot'}
# Out:
# Extracting /data/fashion/train-images-idx3-ubyte.gz
# Extracting /data/fashion/train-labels-idx1-ubyte.gz
# Extracting /data/fashion/t10k-images-idx3-ubyte.gz
# Extracting /data/fashion/t10k-labels-idx1-ubyte.gz

# %%
def data_generator():
    while True:
        images, labels = data.train.next_batch(32)
        images = images.reshape((-1, 28, 28, 1))
        yield (images, labels)

# %% [markdown]
# ## Keras

# %%
import keras as k
from keras.layers import Conv2D, MaxPooling2D, Input, Flatten, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
images = Input(shape=(28, 28, 1))
conv_layer_1 = Conv2D(filters=32, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu', 
                      kernel_initializer='glorot_uniform')(images)
conv_layer_1 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same')(conv_layer_1)

conv_layer_2 = Conv2D(filters=64, kernel_size=(3, 3), strides=(1, 1), padding='same', activation='relu')(conv_layer_1)
conv_layer_2 = MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same')(conv_layer_2)

flatten_layer = Flatten()(conv_layer_2)
prediction = Dense(10, activation='softmax')(flatten_layer)

model = Model(inputs=images, outputs=prediction)

# %%
conv_layer_1._keras_shape, conv_layer_2._keras_shape
# Out:
# ((None, 14, 14, 32), (None, 7, 7, 64))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['mse', 'accuracy'])

# %%
valid_images = data.validation.images.reshape((-1, 28, 28, 1))
valid_labels = data.validation.labels

# %%
valid_images.shape, valid_labels.shape
# Out:
# ((5000, 28, 28, 1), (5000, 10))

# %%
model.fit_generator(data_generator(), steps_per_epoch=3, epochs=50,
          validation_data=(valid_images, valid_labels))
# Out:
# Epoch 1/50
# 3/3 [==============================] - 4s 1s/step - loss: 2.2678 - mean_squared_error: 0.0893 - acc: 0.1562 - val_loss: 2.2326 - val_mean_squared_error: 0.0886 - val_acc: 0.1022
# Epoch 2/50
# 3/3 [==============================] - 1s 248ms/step - loss: 2.2339 - mean_squared_error: 0.0888 - acc: 0.0625 - val_loss: 2.1188 - val_mean_squared_error: 0.0862 - val_acc: 0.2610
# Epoch 3/50
# 3/3 [==============================] - 1s 244ms/step - loss: 2.0712 - mean_squared_error: 0.0851 - acc: 0.4062 - val_loss: 1.9648 - val_mean_squared_error: 0.0825 - val_acc: 0.5312
# Epoch 4/50
# 3/3 [==============================] - 1s 244ms/step - loss: 1.9258 - mean_squared_error: 0.0812 - acc: 0.5521 - val_loss: 1.7746 - val_mean_squared_error: 0.0770 - val_acc: 0.5810
# Epoch 5/50
# 3/3 [==============================] - 1s 244ms/step - loss: 1.6967 - mean_squared_error: 0.0740 - acc: 0.5625 - val_loss: 1.5930 - val_mean_squared_error: 0.0707 - val_acc: 0.4746
# Epoch 6/50
# 3/3 [==============================] - 1s 245ms/step - loss: 1.5932 - mean_squared_error: 0.0707 - acc: 0.4271 - val_loss: 1.3553 - val_mean_squared_error: 0.0623 - val_acc: 0.5296
# Epoch 7/50
# 3/3 [==============================] - 1s 244ms/step - loss: 1.2352 - mean_squared_error: 0.0578 - acc: 0.5625 - val_loss: 1.1551 - val_mean_squared_error: 0.0563 - val_acc: 0.5430
# Epoch 8/50
# 3/3 [==============================] - 1s 245ms/step - loss: 0.9324 - mean_squared_error: 0.0448 - acc: 0.7396 - val_loss: 1.0636 - val_mean_squared_error: 0.0535 - val_acc: 0.5818
# Epoch 9/50
# 3/3 [==============================] - 1s 244ms/step - loss: 1.1621 - mean_squared_error: 0.0566 - acc: 0.5521 - val_loss: 0.9364 - val_mean_squared_error: 0.0478 - val_acc: 0.6188
# Epoch 10/50
# 3/3 [==============================] - 1s 246ms/step - loss: 0.8801 - mean_squared_error: 0.0484 - acc: 0.5938 - val_loss: 0.9125 - val_mean_squared_error: 0.0460 - val_acc: 0.6618
# Epoch 11/50
# 3/3 [==============================] - 1s 251ms/step - loss: 0.8595 - mean_squared_error: 0.0436 - acc: 0.7083 - val_loss: 0.8806 - val_mean_squared_error: 0.0444 - val_acc: 0.6840
# Epoch 12/50
# 3/3 [==============================] - 1s 251ms/step - loss: 0.9782 - mean_squared_error: 0.0465 - acc: 0.6562 - val_loss: 0.8592 - val_mean_squared_error: 0.0435 - val_acc: 0.6630
# Epoch 13/50
# 3/3 [==============================] - 1s 255ms/step - loss: 0.7256 - mean_squared_error: 0.0398 - acc: 0.6667 - val_loss: 0.8102 - val_mean_squared_error: 0.0409 - val_acc: 0.6988
# Epoch 14/50
# 3/3 [==============================] - 1s 255ms/step - loss: 0.6658 - mean_squared_error: 0.0344 - acc: 0.7500 - val_loss: 0.8296 - val_mean_squared_error: 0.0409 - val_acc: 0.6962
# Epoch 15/50
# 3/3 [==============================] - 1s 250ms/step - loss: 0.8900 - mean_squared_error: 0.0433 - acc: 0.7292 - val_loss: 0.8075 - val_mean_squared_error: 0.0398 - val_acc: 0.7190
# Epoch 16/50
# 3/3 [==============================] - 1s 251ms/step - loss: 0.7298 - mean_squared_error: 0.0381 - acc: 0.6771 - val_loss: 0.8458 - val_mean_squared_error: 0.0410 - val_acc: 0.6940
# Epoch 17/50
# 3/3 [==============================] - 1s 251ms/step - loss: 0.9592 - mean_squared_error: 0.0401 - acc: 0.7188 - val_loss: 0.9255 - val_mean_squared_error: 0.0429 - val_acc: 0.6824
# Epoch 18/50
# 3/3 [==============================] - 1s 254ms/step - loss: 0.6006 - mean_squared_error: 0.0301 - acc: 0.7708 - val_loss: 0.7933 - val_mean_squared_error: 0.0401 - val_acc: 0.6986
# Epoch 19/50
# 3/3 [==============================] - 1s 257ms/step - loss: 0.8517 - mean_squared_error: 0.0398 - acc: 0.7083 - val_loss: 0.8081 - val_mean_squared_error: 0.0418 - val_acc: 0.6908
# Epoch 20/50
# 3/3 [==============================] - 1s 282ms/step - loss: 0.7596 - mean_squared_error: 0.0387 - acc: 0.7188 - val_loss: 0.7669 - val_mean_squared_error: 0.0389 - val_acc: 0.7148
# Epoch 21/50
# 3/3 [==============================] - 1s 278ms/step - loss: 0.8139 - mean_squared_error: 0.0393 - acc: 0.7083 - val_loss: 0.7114 - val_mean_squared_error: 0.0353 - val_acc: 0.7572
# Epoch 22/50
# 3/3 [==============================] - 1s 246ms/step - loss: 0.7785 - mean_squared_error: 0.0409 - acc: 0.7188 - val_loss: 0.7570 - val_mean_squared_error: 0.0379 - val_acc: 0.7140
# Epoch 23/50
# 3/3 [==============================] - 1s 245ms/step - loss: 0.7505 - mean_squared_error: 0.0352 - acc: 0.7188 - val_loss: 0.7160 - val_mean_squared_error: 0.0359 - val_acc: 0.7372
# Epoch 24/50
# 3/3 [==============================] - 1s 267ms/step - loss: 0.8916 - mean_squared_error: 0.0445 - acc: 0.6979 - val_loss: 0.6901 - val_mean_squared_error: 0.0355 - val_acc: 0.7240
# Epoch 25/50
# 3/3 [==============================] - 1s 253ms/step - loss: 0.6183 - mean_squared_error: 0.0312 - acc: 0.7812 - val_loss: 0.7354 - val_mean_squared_error: 0.0374 - val_acc: 0.7048
# Epoch 26/50
# 3/3 [==============================] - 1s 250ms/step - loss: 0.6959 - mean_squared_error: 0.0364 - acc: 0.6979 - val_loss: 0.7272 - val_mean_squared_error: 0.0362 - val_acc: 0.7370
# Epoch 27/50
# 3/3 [==============================] - 1s 251ms/step - loss: 0.6367 - mean_squared_error: 0.0323 - acc: 0.7812 - val_loss: 0.6901 - val_mean_squared_error: 0.0334 - val_acc: 0.7596
# Epoch 28/50
# 3/3 [==============================] - 1s 256ms/step - loss: 0.8158 - mean_squared_error: 0.0364 - acc: 0.7500 - val_loss: 0.7183 - val_mean_squared_error: 0.0354 - val_acc: 0.7474
# Epoch 29/50
# 3/3 [==============================] - 1s 254ms/step - loss: 0.7731 - mean_squared_error: 0.0401 - acc: 0.7083 - val_loss: 0.7075 - val_mean_squared_error: 0.0359 - val_acc: 0.7324
# Epoch 30/50
# 3/3 [==============================] - 1s 262ms/step - loss: 0.7251 - mean_squared_error: 0.0346 - acc: 0.7396 - val_loss: 0.6900 - val_mean_squared_error: 0.0352 - val_acc: 0.7464
# Epoch 31/50
# 3/3 [==============================] - 1s 285ms/step - loss: 0.5771 - mean_squared_error: 0.0295 - acc: 0.7604 - val_loss: 0.6564 - val_mean_squared_error: 0.0329 - val_acc: 0.7632
# Epoch 32/50
# 3/3 [==============================] - 1s 262ms/step - loss: 0.5839 - mean_squared_error: 0.0302 - acc: 0.7708 - val_loss: 0.6610 - val_mean_squared_error: 0.0337 - val_acc: 0.7528
# Epoch 33/50
# 3/3 [==============================] - 1s 284ms/step - loss: 0.5370 - mean_squared_error: 0.0292 - acc: 0.7917 - val_loss: 0.6395 - val_mean_squared_error: 0.0326 - val_acc: 0.7552
# Epoch 34/50
# 3/3 [==============================] - 1s 292ms/step - loss: 0.7304 - mean_squared_error: 0.0350 - acc: 0.7604 - val_loss: 0.6194 - val_mean_squared_error: 0.0315 - val_acc: 0.7640
# Epoch 35/50
# 3/3 [==============================] - 1s 264ms/step - loss: 0.6196 - mean_squared_error: 0.0349 - acc: 0.7292 - val_loss: 0.6561 - val_mean_squared_error: 0.0330 - val_acc: 0.7588
# Epoch 36/50
# 3/3 [==============================] - 1s 268ms/step - loss: 0.8369 - mean_squared_error: 0.0448 - acc: 0.6354 - val_loss: 0.6167 - val_mean_squared_error: 0.0311 - val_acc: 0.7714
# Epoch 37/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.6033 - mean_squared_error: 0.0307 - acc: 0.7396 - val_loss: 0.5927 - val_mean_squared_error: 0.0297 - val_acc: 0.7892
# Epoch 38/50
# 3/3 [==============================] - 1s 273ms/step - loss: 0.5766 - mean_squared_error: 0.0285 - acc: 0.7708 - val_loss: 0.6304 - val_mean_squared_error: 0.0325 - val_acc: 0.7556
# Epoch 39/50
# 3/3 [==============================] - 1s 260ms/step - loss: 0.6256 - mean_squared_error: 0.0312 - acc: 0.7812 - val_loss: 0.5872 - val_mean_squared_error: 0.0298 - val_acc: 0.7770
# Epoch 40/50
# 3/3 [==============================] - 1s 258ms/step - loss: 0.5999 - mean_squared_error: 0.0291 - acc: 0.7708 - val_loss: 0.5642 - val_mean_squared_error: 0.0280 - val_acc: 0.7996
# Epoch 41/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.6381 - mean_squared_error: 0.0339 - acc: 0.7396 - val_loss: 0.6046 - val_mean_squared_error: 0.0302 - val_acc: 0.7762
# Epoch 42/50
# 3/3 [==============================] - 1s 269ms/step - loss: 0.6617 - mean_squared_error: 0.0332 - acc: 0.7500 - val_loss: 0.6056 - val_mean_squared_error: 0.0304 - val_acc: 0.7726
# Epoch 43/50
# 3/3 [==============================] - 1s 293ms/step - loss: 0.5484 - mean_squared_error: 0.0288 - acc: 0.7708 - val_loss: 0.5709 - val_mean_squared_error: 0.0287 - val_acc: 0.7960
# Epoch 44/50
# 3/3 [==============================] - 1s 304ms/step - loss: 0.6377 - mean_squared_error: 0.0313 - acc: 0.8021 - val_loss: 0.5928 - val_mean_squared_error: 0.0303 - val_acc: 0.7796
# Epoch 45/50
# 3/3 [==============================] - 1s 291ms/step - loss: 0.5706 - mean_squared_error: 0.0315 - acc: 0.7708 - val_loss: 0.5984 - val_mean_squared_error: 0.0310 - val_acc: 0.7710
# Epoch 46/50
# 3/3 [==============================] - 1s 267ms/step - loss: 0.6985 - mean_squared_error: 0.0341 - acc: 0.7396 - val_loss: 0.5730 - val_mean_squared_error: 0.0293 - val_acc: 0.7870
# Epoch 47/50
# 3/3 [==============================] - 1s 265ms/step - loss: 0.5233 - mean_squared_error: 0.0274 - acc: 0.8021 - val_loss: 0.5376 - val_mean_squared_error: 0.0269 - val_acc: 0.8104
# Epoch 48/50
# 3/3 [==============================] - 1s 264ms/step - loss: 0.5764 - mean_squared_error: 0.0311 - acc: 0.7500 - val_loss: 0.5527 - val_mean_squared_error: 0.0277 - val_acc: 0.8012
# Epoch 49/50
# 3/3 [==============================] - 1s 266ms/step - loss: 0.6258 - mean_squared_error: 0.0319 - acc: 0.7812 - val_loss: 0.5551 - val_mean_squared_error: 0.0278 - val_acc: 0.7994
# Epoch 50/50
# 3/3 [==============================] - 1s 272ms/step - loss: 0.5933 - mean_squared_error: 0.0322 - acc: 0.7396 - val_loss: 0.5590 - val_mean_squared_error: 0.0281 - val_acc: 0.8034

# %%
_prediction = model.predict(valid_images)

# %% [markdown]
# ## Results evaluation

# %%
from utils.results_evaluation import get_info_df
from utils.results_evaluation import get_accuracy
from utils.results_evaluation import get_false_positives
from utils.results_evaluation import get_info_df
from utils.results_evaluation import get_rec_prec
from utils.results_evaluation import plot_coocurance_matrix
from utils.results_evaluation import plot_examples

# %%
df = get_info_df(data.validation.labels, _prediction, class_id2class_name_mapping, data.validation.images)

# %%
get_accuracy(df)
# Out:
# 80.34

# %%
get_rec_prec(df, class_id2class_name_mapping)
# Out:
#     class_name  precision  recall
# 0  T-shirt/top      68.61   85.12
# 1      Trouser      96.15   94.42
# 2     Pullover      78.17   61.11
# 3        Dress      83.43   84.43
# 4         Coat      59.22   86.89
# 5       Sandal      77.62   99.19
# 6        Shirt      64.41   30.83
# 7      Sneaker      94.04   74.02
# 8          Bag      92.26   94.90
# 9   Ankle boot      93.16   91.50

# %%
fp = get_false_positives(df, 'Shirt')

# %%
plot_examples(fp)

# %%
plot_coocurance_matrix(df, use_top3=False, use_log=False)
